# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---

# %% [markdown]
# # **Análise Exploratória de Dados de Logística**

# %% [markdown]
# ## 1\. Contexto

# %% [markdown]
# Neste projeto estaremos visualizando dados das distribuições das entregas da empresa Loggi, em sua atuação no Distrito Federal. Averiguando as condições de entraga de cada polo e a logistica de distribuição dos veiculos disponiveis.

# %% [markdown]
# ## 2\. Pacotes e bibliotecas

# %%
# !pip3 install geopandas
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopy
import numpy as np
import geopandas
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %% [markdown]
# ## 3\. Exploração de dados

# %% [markdown]
# **3.1 Coleta de Dados**

# %%
with open('deliveries.json', mode='r', encoding='utf8')as file:
  data = json.load(file)
  deliveries_df = pd.DataFrame(data)
  deliveries_df.head()

# %% [markdown]
# *   Apos colocarmos os dados recebidos em um Data Frame daremos inicio ao tratamento dos dados

# %% [markdown]
# 3.2 Wrangling

# %%
hub_oring_df = pd.json_normalize(deliveries_df['origin'])
hub_oring_df.head()
# Out:
#          lng        lat
# 0 -48.054989 -15.838145
# 1 -48.054989 -15.838145
# 2 -48.054989 -15.838145
# 3 -47.893662 -15.805118
# 4 -48.054989 -15.838145

# %%
deliveries_df = pd.merge(left=deliveries_df, right=hub_oring_df, how='inner', left_index=True, right_index=True)
deliveries_df.head()
# Out:
#            name region                                             origin  \
# 0  cvrp-2-df-33   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 1  cvrp-2-df-73   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 2  cvrp-2-df-20   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
# 3  cvrp-1-df-71   df-1  {'lng': -47.89366206897872, 'lat': -15.8051175...
# 4  cvrp-2-df-87   df-2  {'lng': -48.05498915846707, 'lat': -15.8381445...
#
#    vehicle_capacity                                         deliveries  \
# 0               180  [{'id': '313483a19d2f8d65cd5024c8d215cfbd', 'p...
# 1               180  [{'id': 'bf3fc630b1c29601a4caf1bdd474b85', 'po...
# 2               180  [{'id': 'b30f1145a2ba4e0b9ac0162b68d045c3', 'p...
# 3               180  [{'id': 'be3ed547394196c12c7c27c89ac74ed6', 'p...
# 4               180  [{'id': 'a6328fb4dc0654eb28a996a270b0f6e4', 'p...
#
#          lng        lat
# 0 -48.054989 -15.838145
# 1 -48.054989 -15.838145
# ...

# %% [markdown]
# - **Coluna** : Oring

# %%
deliveries_df = deliveries_df.drop('origin', axis=1)
deliveries_df = deliveries_df[["name", "region", "lng", "lat", "vehicle_capacity", "deliveries"]]
deliveries_df.head()
# Out:
#            name region        lng        lat  vehicle_capacity  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145               180
# 1  cvrp-2-df-73   df-2 -48.054989 -15.838145               180
# 2  cvrp-2-df-20   df-2 -48.054989 -15.838145               180
# 3  cvrp-1-df-71   df-1 -47.893662 -15.805118               180
# 4  cvrp-2-df-87   df-2 -48.054989 -15.838145               180
#
#                                           deliveries
# 0  [{'id': '313483a19d2f8d65cd5024c8d215cfbd', 'p...
# 1  [{'id': 'bf3fc630b1c29601a4caf1bdd474b85', 'po...
# 2  [{'id': 'b30f1145a2ba4e0b9ac0162b68d045c3', 'p...
# 3  [{'id': 'be3ed547394196c12c7c27c89ac74ed6', 'p...
# 4  [{'id': 'a6328fb4dc0654eb28a996a270b0f6e4', 'p...

# %%
deliveries_df.rename(columns={"lng": "hub_lng", "lat": "hub_lat"}, inplace=True)
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat  vehicle_capacity  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145               180
# 1  cvrp-2-df-73   df-2 -48.054989 -15.838145               180
# 2  cvrp-2-df-20   df-2 -48.054989 -15.838145               180
# 3  cvrp-1-df-71   df-1 -47.893662 -15.805118               180
# 4  cvrp-2-df-87   df-2 -48.054989 -15.838145               180
#
#                                           deliveries
# 0  [{'id': '313483a19d2f8d65cd5024c8d215cfbd', 'p...
# 1  [{'id': 'bf3fc630b1c29601a4caf1bdd474b85', 'po...
# 2  [{'id': 'b30f1145a2ba4e0b9ac0162b68d045c3', 'p...
# 3  [{'id': 'be3ed547394196c12c7c27c89ac74ed6', 'p...
# 4  [{'id': 'a6328fb4dc0654eb28a996a270b0f6e4', 'p...

# %% [markdown]
# - **Coluna**: deliveries
#
# Repare que a coluna `deliveries` contem dados uma lista de dados `nested` ou aninhados na estrutura do JSON. Vamos normalizar a coluna com uma operação conhecida como `explode` ou explosão que transforma cada elemento da lista em uma linha. Por fim, faremos os `flatten` ou achatamento do resultado coluna:

# %%
deliveries_exploded_df = deliveries_df[["deliveries"]].explode("deliveries")
deliveries_exploded_df.head()
# Out:
#                                           deliveries
# 0  {'id': '313483a19d2f8d65cd5024c8d215cfbd', 'po...
# 0  {'id': '320c94b17aa685c939b3f3244c3099de', 'po...
# 0  {'id': '3663b42f4b8decb33059febaba46d5c8', 'po...
# 0  {'id': 'e11ab58363c38d6abc90d5fba87b7d7', 'poi...
# 0  {'id': '54cb45b7bbbd4e34e7150900f92d7f4b', 'po...

# %%
deliveries_normalized_df = pd.concat([
    pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["size"])).rename(columns={"deliveries": "delivery_size"}),
    pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["point"]["lng"])).rename(columns={"deliveries": "delivery_lng"}),
    pd.DataFrame(deliveries_exploded_df["deliveries"].apply(lambda record: record["point"]["lat"])).rename(columns={"deliveries": "delivery_lat"}),
], axis=1)
deliveries_normalized_df.head()
# Out:
#    delivery_size  delivery_lng  delivery_lat
# 0              9    -48.116189    -15.848929
# 0              2    -48.118195    -15.850772
# 0              1    -48.112483    -15.847871
# 0              2    -48.118023    -15.846471
# 0              7    -48.114898    -15.858055

# %% [markdown]
# Apos explodimos esse dados, iremos normaliza-los e retorna-los ao conjundo principal

# %%
deliveries_df = deliveries_df.drop("deliveries", axis=1)
deliveries_df = pd.merge(left=deliveries_df, right=deliveries_normalized_df, how='right', left_index=True, right_index=True)
deliveries_df.reset_index(inplace=True, drop=True)
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat  vehicle_capacity  delivery_size  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              9
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              2
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              1
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              2
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              7
#
#    delivery_lng  delivery_lat
# 0    -48.116189    -15.848929
# 1    -48.118195    -15.850772
# 2    -48.112483    -15.847871
# 3    -48.118023    -15.846471
# 4    -48.114898    -15.858055

# %%
len(deliveries_df)
# Out:
# 636149

# %% [markdown]
# 3.3 **Estrutura**
#
# Agora podemos analisar a estrutura desses dados

# %%
deliveries_df.shape
# Out:
# (636149, 8)

# %%
deliveries_df.columns
# Out:
# Index(['name', 'region', 'hub_lng', 'hub_lat', 'vehicle_capacity',
#        'delivery_size', 'delivery_lng', 'delivery_lat'],
#       dtype='object')

# %%
deliveries_df.index
# Out:
# RangeIndex(start=0, stop=636149, step=1)

# %%
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636149 entries, 0 to 636148
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              636149 non-null  object
#  1   region            636149 non-null  object
#  2   hub_lng           636149 non-null  float64
#  3   hub_lat           636149 non-null  float64
#  4   vehicle_capacity  636149 non-null  int64
#  5   delivery_size     636149 non-null  int64
#  6   delivery_lng      636149 non-null  float64
#  7   delivery_lat      636149 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 38.8+ MB

# %% [markdown]
# 3.4 **schema**

# %%
deliveries_df.head(n=5)
# Out:
#            name region    hub_lng    hub_lat  vehicle_capacity  delivery_size  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              9
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              2
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              1
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              2
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145               180              7
#
#    delivery_lng  delivery_lat
# 0    -48.116189    -15.848929
# 1    -48.118195    -15.850772
# 2    -48.112483    -15.847871
# 3    -48.118023    -15.846471
# 4    -48.114898    -15.858055

# %%
deliveries_df.dtypes
# Out:
# name                 object
# region               object
# hub_lng             float64
# hub_lat             float64
# vehicle_capacity      int64
# delivery_size         int64
# delivery_lng        float64
# delivery_lat        float64
# dtype: object

# %% [markdown]
# Atributos **categóricos**.

# %%
deliveries_df.select_dtypes("object").describe().transpose()
# Out:
#          count unique           top    freq
# name    636149    199  cvrp-1-df-87    5636
# region  636149      3          df-1  304708

# %% [markdown]
# Atributos **numéricos**
#
#
# ---

# %%
deliveries_df.drop(["name","region"], axis=1).select_dtypes("int64").describe().transpose()
# Out:
#                      count        mean       std    min    25%    50%    75%  \
# vehicle_capacity  636149.0  180.000000  0.000000  180.0  180.0  180.0  180.0
# delivery_size     636149.0    5.512111  2.874557    1.0    3.0    6.0    8.0
#
#                     max
# vehicle_capacity  180.0
# delivery_size      10.0

# %% [markdown]
# 3.5 **Dados faltantes**
# Com o comando .isna().any() podemos vereficar se nas columnas existão dados faltantes

# %%
deliveries_df.isna().any()
# Out:
# name                False
# region              False
# hub_lng             False
# hub_lat             False
# vehicle_capacity    False
# delivery_size       False
# delivery_lng        False
# delivery_lat        False
# dtype: bool

# %% [markdown]
# ## 4\. Manipulação
#
# Após passarmos pelos porcedimentos de extração dos dados em seu arquivo bruto podemos iniciar a sua manipulação

# %% [markdown]
# 1.1 **geocodicação e enrriquecimento**
#
#
# - Geocodificação reversa do hub

# %%
hub_df = deliveries_df[["region", "hub_lng", "hub_lat"]]
hub_df = hub_df.drop_duplicates().sort_values(by="region").reset_index(drop=True)
hub_df.head()
# Out:
#   region    hub_lng    hub_lat
# 0   df-0 -47.802665 -15.657014
# 1   df-1 -47.893662 -15.805118
# 2   df-2 -48.054989 -15.838145

# %%
geolocator = Nominatim(user_agent="ebac_geocoder")
location = geolocator.reverse("-15.657013854445248, -47.802664728268745")

print(json.dumps(location.raw, indent=2, ensure_ascii=False))

geocoder = RateLimiter(geolocator.reverse, min_delay_seconds=1)
# Out:
# {
#   "place_id": 46410411,
#   "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#   "osm_type": "way",
#   "osm_id": 240210480,
#   "lat": "-15.656916027876347",
#   "lon": "-47.80264463632131",
#   "class": "highway",
#   "type": "secondary",
#   "place_rank": 26,
#   "importance": 0.0533433333333333,
#   "addresstype": "road",
#   "name": "Rua 7",
#   "display_name": "Rua 7, Quadra 2, Sobradinho, Região Geográfica Imediata do Distrito Federal, Região Integrada de Desenvolvimento do Distrito Federal e Entorno, Região Geográfica Intermediária do Distrito Federal, Distrito Federal, Região Centro-Oeste, 73015-127, Brasil",
#   "address": {
#     "road": "Rua 7",
#     "residential": "Quadra 2",
#     "suburb": "Sobradinho",
#     "town": "Sobradinho",
#     "municipality": "Região Geográfica Imediata do Distrito Federal",
#     "county": "Região Integrada de Desenvolvimento do Distrito Federal e Entorno",
# ...

# %% [markdown]
# Agora aplicaremos a geocodificação nas três regiões e extrair informações de cidade e bairro

# %%
geocoder = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# %%
hub_df["coordinates"] = hub_df["hub_lat"].astype(str)  + ", " + hub_df["hub_lng"].astype(str)
hub_df["geodata"] = hub_df["coordinates"].apply(geocoder)
hub_df.head()
# Out:
#   region    hub_lng    hub_lat                               coordinates  \
# 0   df-0 -47.802665 -15.657014  -15.657013854445248, -47.802664728268745
# 1   df-1 -47.893662 -15.805118    -15.80511751066334, -47.89366206897872
# 2   df-2 -48.054989 -15.838145    -15.83814451122274, -48.05498915846707
#
#                                              geodata
# 0  (Rua 7, Quadra 2, Sobradinho, Região Geográfic...
# 1  (SQS 303, Asa Sul, Brasília, Plano Piloto, Reg...
# 2  (Armazém do Bolo, lote 4/8, CSB 4/5, Taguating...

# %%
hub_geodata_df = pd.json_normalize(hub_df["geodata"].apply(lambda data: data.raw))
hub_geodata_df.head()
# Out:
#    place_id                                            licence osm_type  \
# 0  46410411  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 1  46401425  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
# 2  43777060  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
#
#        osm_id                  lat                 lon    class         type  \
# 0   240210480  -15.656916027876347  -47.80264463632131  highway    secondary
# 1    66353368  -15.805172753950067  -47.89372354453109  highway  residential
# 2  6249717596          -15.8384371         -48.0552917     shop       pastry
#
#    place_rank  importance  ...     address.state address.ISO3166-2-lvl4  \
# 0          26    0.053343  ...  Distrito Federal                  BR-DF
# 1          26    0.053411  ...  Distrito Federal                  BR-DF
# 2          30    0.000010  ...  Distrito Federal                  BR-DF
#
# ...

# %%
hub_geodata_df = hub_geodata_df[["address.town", "address.suburb", "address.city"]]
hub_geodata_df.rename(columns={"address.town": "hub_town", "address.suburb": "hub_suburb", "address.city": "hub_city"}, inplace=True)
hub_geodata_df["hub_city"] = np.where(hub_geodata_df["hub_city"].notna(), hub_geodata_df["hub_city"], hub_geodata_df["hub_town"])
hub_geodata_df["hub_suburb"] = np.where(hub_geodata_df["hub_suburb"].notna(), hub_geodata_df["hub_suburb"], hub_geodata_df["hub_city"])
hub_geodata_df = hub_geodata_df.drop("hub_town", axis=1)
hub_geodata_df.head()
# Out:
#    hub_suburb    hub_city
# 0  Sobradinho  Sobradinho
# 1     Asa Sul    Brasília
# 2  Taguatinga  Taguatinga

# %% [markdown]
# O DataFrame `hub_geodata_df` agora é combinado ao DataFrame principal `deliveries_df`.

# %%
hub_df = pd.merge(left=hub_df, right=hub_geodata_df, left_index=True, right_index=True)
hub_df = hub_df[["region","hub_suburb","hub_city"]]
hub_df.head()
# Out:
#   region  hub_suburb    hub_city
# 0   df-0  Sobradinho  Sobradinho
# 1   df-1     Asa Sul    Brasília
# 2   df-2  Taguatinga  Taguatinga

# %%
deliveries_df = pd.merge(left=deliveries_df, right=hub_df, how="inner", on="region")
deliveries_df = deliveries_df[["name", "region", "hub_lng", "hub_lat", "hub_city", "hub_suburb", "vehicle_capacity", "delivery_size", "delivery_lng", "delivery_lat"]]
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055

# %% [markdown]
# - **Geocodificação reversa da entrega**

# %%
# !wget -q "https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries-geodata.csv" -O deliveries-geodata.csv
deliveries_geodata_df = pd.read_csv("deliveries-geodata.csv")
deliveries_geodata_df.head()
# Out:
#    delivery_lng  delivery_lat            delivery_city  \
# 0    -48.116189    -15.848929                Ceilândia
# 1    -48.118195    -15.850772                Ceilândia
# 2    -48.112483    -15.847871                Ceilândia
# 3    -48.118023    -15.846471                Ceilândia
# 4    -48.114898    -15.858055  Sol Nascente/Pôr do Sol
#
#            delivery_suburb
# 0                    P Sul
# 1                    P Sul
# 2                    P Sul
# 3                    P Sul
# 4  Sol Nascente/Pôr do Sol

# %%
deliveries_df = pd.merge(left=deliveries_df, right=deliveries_geodata_df[["delivery_city", "delivery_suburb"]], how="inner", left_index=True, right_index=True)
deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat  \
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055
#
#              delivery_city          delivery_suburb
# 0                Ceilândia                    P Sul
# 1                Ceilândia                    P Sul
# ...

# %% [markdown]
# ## 5\. Visualização

# %% [markdown]
# *   Mapa do Distrito Federal
#
#
# Aqui faremos o download do mapa do Distrito Federal no site da IBGE

# %%
# !wget -q "https://geoftp.ibge.gov.br/cartas_e_mapas/bases_cartograficas_continuas/bc100/go_df/versao2016/shapefile/bc100_go_df_shp.zip" -O distrito-federal.zip
# !unzip -q distrito-federal.zip -d ./maps
# !cp ./maps/LIM_Unidade_Federacao_A.shp ./distrito-federal.shp
# !cp ./maps/LIM_Unidade_Federacao_A.shx ./distrito-federal.shx

# %%
mapa = geopandas.read_file("distrito-federal.shp")
mapa = mapa.loc[[0]]
mapa.head()
# Out:
#                                             geometry
# 0  POLYGON Z ((-47.31048 -16.03602 0, -47.31057 -...

# %% [markdown]
# *   Mapa dos Hubs

# %%
hub_df = deliveries_df[["region","hub_lng", "hub_lat"]].drop_duplicates().reset_index(drop=True)
geo_hub_df = geopandas.GeoDataFrame(hub_df, geometry=geopandas.points_from_xy(hub_df["hub_lng"], hub_df["hub_lat"]))
geo_hub_df.head()
# Out:
#   region    hub_lng    hub_lat                     geometry
# 0   df-2 -48.054989 -15.838145  POINT (-48.05499 -15.83814)
# 1   df-1 -47.893662 -15.805118  POINT (-47.89366 -15.80512)
# 2   df-0 -47.802665 -15.657014  POINT (-47.80266 -15.65701)

# %% [markdown]
# *   Mapa das entregas

# %%
geo_deliveries_df = geopandas.GeoDataFrame(deliveries_df, geometry=geopandas.points_from_xy(deliveries_df["delivery_lng"], deliveries_df["delivery_lat"]))
geo_deliveries_df.head()
# Out:
#            name region    hub_lng    hub_lat    hub_city  hub_suburb  \
# 0  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 1  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 2  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 3  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
# 4  cvrp-2-df-33   df-2 -48.054989 -15.838145  Taguatinga  Taguatinga
#
#    vehicle_capacity  delivery_size  delivery_lng  delivery_lat  \
# 0               180              9    -48.116189    -15.848929
# 1               180              2    -48.118195    -15.850772
# 2               180              1    -48.112483    -15.847871
# 3               180              2    -48.118023    -15.846471
# 4               180              7    -48.114898    -15.858055
#
#              delivery_city          delivery_suburb  \
# 0                Ceilândia                    P Sul
# 1                Ceilândia                    P Sul
# ...

# %% [markdown]
# *   **Vizualização**

# %%
# cria uma figura vazia
fig, ax = plt.subplots(figsize = (50/2.54, 50/2.54))

# cria o mapa da cidade
mapa.plot(ax=ax, alpha= 0.4, color="lightgrey")

# plot das entregas
geo_deliveries_df.query("region == 'df-0'").plot(ax=ax, markersize=1, color="red", label="df-0")
geo_deliveries_df.query("region == 'df-1'").plot(ax=ax, markersize=1, color="blue", label="df-1")
geo_deliveries_df.query("region == 'df-2'").plot(ax=ax, markersize=1, color="seagreen", label="df-2")

#plot dos hubs
geo_hub_df.plot(ax=ax, markersize=30, marker= "x", color="black", label="hub")

# legenda
plt.title("Entregas no Distrito Federal por Regiao", fontdict={"fontsize": 16})
lgnd = plt.legend(prop={"size":15})
for handle in lgnd.legendHandles:
  handle.set_sizes([50])
# Out:
# <ipython-input-55-11deaa6b2ca3>:18: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in lgnd.legendHandles:

# %% [markdown]
# *   Aqui podemos vizualizar a propoção das entregas distribuidas por cada hub.
#
# * Notasse que no hub 0 e 2 a uma maior atuação de demandas distantes do centro do polo
#
# * Ja no polo 1 a grande demanda porem esta melhor centralizada

# %% [markdown]
# **Entregas por regiao**

# %%
data = pd.DataFrame(deliveries_df[['region', 'vehicle_capacity']].value_counts(normalize=True)).reset_index()
data.rename(columns={0: "region_percent"}, inplace=True)
data.head()
# Out:
#   region  vehicle_capacity  proportion
# 0   df-1               180    0.478988
# 1   df-2               180    0.410783
# 2   df-0               180    0.110229

# %%
with sns.axes_style('whitegrid'):
  grafico = sns.barplot(data=data, x="region", y="proportion", ci=None, palette="pastel")
  grafico.set(title='Proporção de entregas por região', xlabel='Região', ylabel='Proporção');
# Out:
# <ipython-input-64-4e5092e1fa1e>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   grafico = sns.barplot(data=data, x="region", y="proportion", ci=None, palette="pastel")
# <ipython-input-64-4e5092e1fa1e>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   grafico = sns.barplot(data=data, x="region", y="proportion", ci=None, palette="pastel")

# %% [markdown]
# * A distribuiçao de entregas esta em sua maior concentração nos hubs 1 e 2. Dando assim a possibilidade de realocação de veiculos para hubs com mais entregas.
